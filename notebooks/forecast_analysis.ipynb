# %%
import pandas as pd

# %%
df = pd.read_csv("../data/outputs/weekly_forecasts.csv")

# %%
df.model_version.value_counts()
# Out:
# model_version
# weekly_model_v3_calendar      1680
# weekly_model_v4_promotions     840
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    week_start  store_id  product_id  predicted_units forecast_created_at  \
# 0  2026-03-30         1        1001             7.31          2026-04-06
# 1  2026-03-30         1        1002            12.27          2026-04-06
# 2  2026-03-30         1        1003            24.83          2026-04-06
# 3  2026-03-30         1        1004             6.84          2026-04-06
# 4  2026-03-30         1        1005            29.16          2026-04-06
#
#                 model_version
# 0  weekly_model_v4_promotions
# 1  weekly_model_v4_promotions
# 2  weekly_model_v4_promotions
# 3  weekly_model_v4_promotions
# 4  weekly_model_v4_promotions

# %%
display(df[["store_name","product_name","category","predicted_units","regular_price"]].head(15))

# %%
display(df[["week_start", "store_id", "product_id", "predicted_units", "forecast_created_at"]].head())
# Out:
#    week_start  store_id  product_id  predicted_units forecast_created_at
# 0  2026-03-30         1        1001             7.31          2026-04-06
# 1  2026-03-30         1        1002            12.27          2026-04-06
# 2  2026-03-30         1        1003            24.83          2026-04-06
# 3  2026-03-30         1        1004             6.84          2026-04-06
# 4  2026-03-30         1        1005            29.16          2026-04-06

# %%
df[["week_start", "store_id", "product_id", "predicted_units", "forecast_created_at"]].head()
# Out:
#    week_start  store_id  product_id  predicted_units forecast_created_at
# 0  2026-03-30         1        1001             7.31          2026-04-06
# 1  2026-03-30         1        1002            12.27          2026-04-06
# 2  2026-03-30         1        1003            24.83          2026-04-06
# 3  2026-03-30         1        1004             6.84          2026-04-06
# 4  2026-03-30         1        1005            29.16          2026-04-06

# %%
from IPython.display import display

print("Forecast sample:")
df.head()
# Out:
# Forecast sample:
#    week_start  store_id  product_id  predicted_units forecast_created_at  \
# 0  2026-03-30         1        1001             7.31          2026-04-06
# 1  2026-03-30         1        1002            12.27          2026-04-06
# 2  2026-03-30         1        1003            24.83          2026-04-06
# 3  2026-03-30         1        1004             6.84          2026-04-06
# 4  2026-03-30         1        1005            29.16          2026-04-06
#
#                 model_version
# 0  weekly_model_v4_promotions
# 1  weekly_model_v4_promotions
# 2  weekly_model_v4_promotions
# 3  weekly_model_v4_promotions
# 4  weekly_model_v4_promotions

# %%
from IPython.display import display

print("Forecast sample:")
display(df.head())
# Out:
# Forecast sample:
#    week_start  store_id  product_id  predicted_units forecast_created_at  \
# 0  2026-03-30         1        1001             7.31          2026-04-06
# 1  2026-03-30         1        1002            12.27          2026-04-06
# 2  2026-03-30         1        1003            24.83          2026-04-06
# 3  2026-03-30         1        1004             6.84          2026-04-06
# 4  2026-03-30         1        1005            29.16          2026-04-06
#
#                 model_version
# 0  weekly_model_v4_promotions
# 1  weekly_model_v4_promotions
# 2  weekly_model_v4_promotions
# 3  weekly_model_v4_promotions
# 4  weekly_model_v4_promotions
